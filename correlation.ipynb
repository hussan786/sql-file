# %%
import pandas as pd

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib as plt

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
#create dataframe
code= {
    's':[76,67,42,55],
    't':[63,76,2,11],
    'u':[65,8,94,54],
    'v':[34,9,24,64]
}
df = pd.DataFrame(code,index=["alen","halen","ali","farri"])

# %%
import matplotlib.pyplot as plt

# %%
# Load the tips dataset
tips = sns.load_dataset('tips')

# Display rows of the dataset
print(tips.head())

# Create a scatter plot of total bill vs. tip
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='day', style='time')

# Add title and labels
plt.title('Total Bill vs Tip')
plt.xlabel('Total Bill ($)')
plt.ylabel('Tip ($)')

# Show the plot
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas

# %%
import pandas as pd

# create dataframe
data = {
    "Temperature": [22, 25, 32, 28, 30],
    "cake_Sales": [105, 120, 135, 130, 125]
}

df = pd.DataFrame(data)

# calculate correlation matrix
print(df.corr())
# Out:
#              Temperature  cake_Sales
# Temperature     1.000000    0.923401
# cake_Sales      0.923401    1.000000

# %%
import pandas as pd

# create dataframe
code = {
    "Temp": [22, 65, 32, 55, 30],
    "Sales": [105, 120, 135, 130, 125]
}

df = pd.DataFrame(code)

# calculate correlation 
correlation = df['Temp'].corr(df["Sales"])

print(correlation)
# Out:
# 0.28296382877031
